# %%
from IPython.display import IFrame 
wikiLink="https://en.wikipedia.org/wiki/2020_United_States_census#State_rankings"
IFrame(wikiLink,width=900,height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="https://en.wikipedia.org/wiki/2020_United_States_census#State_rankings"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
wikiTables=pd.read_html(wikiLink,
                           header=0,
                           flavor='bs4',
                           attrs={'class':'wikitable sortable'})
wikiTables
# Out:
# [   Rank                 State  Population as of 2010 census[78]  \
#  0     1            California                          37253956
#  1     2                 Texas                          25145561
#  2     3               Florida                          18801310
#  3     4              New York                          19378102
#  4     5          Pennsylvania                          12702379
#  5     6              Illinois                          12830632
#  6     7                  Ohio                          11536504
#  7     8               Georgia                           9687653
#  8     9        North Carolina                           9535483
#  9    10              Michigan                           9883640
#  10   11            New Jersey                           8791894
#  11   12              Virginia                           8001024
#  12   13            Washington                           6724540
# ...

# %%
wikiTables[0]
# Out:
#    Rank                 State  Population as of 2010 census[78]  \
# 0     1            California                          37253956
# 1     2                 Texas                          25145561
# 2     3               Florida                          18801310
# 3     4              New York                          19378102
# 4     5          Pennsylvania                          12702379
# 5     6              Illinois                          12830632
# 6     7                  Ohio                          11536504
# 7     8               Georgia                           9687653
# 8     9        North Carolina                           9535483
# 9    10              Michigan                           9883640
# 10   11            New Jersey                           8791894
# 11   12              Virginia                           8001024
# 12   13            Washington                           6724540
# 13   14               Arizona                           6392017
# ...

# %%
DFwiki=wikiTables[0].copy()

# %%
DFwiki.columns
# Out:
# Index(['Rank', 'State', 'Population as of 2010 census[78]',
#        'Population as of 2020 census[79]', 'Change', 'Percent change'],
#       dtype='object')

# %%
bye=[0,2,4,5]
DFwiki.drop(columns=DFwiki.columns[bye],inplace=True)#inplace!!
DFwiki
# Out:
#                    State  Population as of 2020 census[79]
# 0             California                          39538223
# 1                  Texas                          29145505
# 2                Florida                          21538187
# 3               New York                          20201249
# 4           Pennsylvania                          13002700
# 5               Illinois                          12812508
# 6                   Ohio                          11799448
# 7                Georgia                          10711908
# 8         North Carolina                          10439388
# 9               Michigan                          10077331
# 10            New Jersey                           9288994
# 11              Virginia                           8631393
# 12            Washington                           7705281
# 13               Arizona                           7151502
# 14         Massachusetts                           7029917
# ...

# %%
DFwiki.columns.to_list()
# Out:
# ['State', 'Population as of 2020 census[79]']

# %%
DFwiki.rename(columns=
              {'Population as of 2020 census[79]':'Population'},
              inplace = True)

# %%
DFwiki.columns
# Out:
# Index(['State', 'Population'], dtype='object')

# %%
DFwiki.iloc[:,:2]
# Out:
#                    State  Population
# 0             California    39538223
# 1                  Texas    29145505
# 2                Florida    21538187
# 3               New York    20201249
# 4           Pennsylvania    13002700
# 5               Illinois    12812508
# 6                   Ohio    11799448
# 7                Georgia    10711908
# 8         North Carolina    10439388
# 9               Michigan    10077331
# 10            New Jersey     9288994
# 11              Virginia     8631393
# 12            Washington     7705281
# 13               Arizona     7151502
# 14         Massachusetts     7029917
# 15             Tennessee     6910840
# 16               Indiana     6785528
# 17              Maryland     6177224
# 18              Missouri     6154913
# 19             Wisconsin     5893718
# 20              Colorado     5773714
# 21             Minnesota     5706494
# 22        South Carolina     5118425
# 23               Alabama     5024279
# ...

# %%
#Checking for leading/trailing spaces
"Washington".strip()
# Out:
# 'Washington'

# %%
DFwiki.head()
# Out:
#           State  Population
# 0    California    39538223
# 1         Texas    29145505
# 2       Florida    21538187
# 3      New York    20201249
# 4  Pennsylvania    13002700

# %%
#delete a single row by index value 0
#axis 1 = column
#axis 0 = row
#we've just dropped "United States"
DFwiki.drop(labels= 51,axis=0)
# Out:
#                    State  Population
# 0             California    39538223
# 1                  Texas    29145505
# 2                Florida    21538187
# 3               New York    20201249
# 4           Pennsylvania    13002700
# 5               Illinois    12812508
# 6                   Ohio    11799448
# 7                Georgia    10711908
# 8         North Carolina    10439388
# 9               Michigan    10077331
# 10            New Jersey     9288994
# 11              Virginia     8631393
# 12            Washington     7705281
# 13               Arizona     7151502
# 14         Massachusetts     7029917
# 15             Tennessee     6910840
# 16               Indiana     6785528
# 17              Maryland     6177224
# 18              Missouri     6154913
# 19             Wisconsin     5893718
# 20              Colorado     5773714
# 21             Minnesota     5706494
# 22        South Carolina     5118425
# 23               Alabama     5024279
# ...

# %%
DFwiki=DFwiki.drop(labels= 51,axis=0)

# %%
DFwiki
# Out:
#                    State  Population
# 0             California    39538223
# 1                  Texas    29145505
# 2                Florida    21538187
# 3               New York    20201249
# 4           Pennsylvania    13002700
# 5               Illinois    12812508
# 6                   Ohio    11799448
# 7                Georgia    10711908
# 8         North Carolina    10439388
# 9               Michigan    10077331
# 10            New Jersey     9288994
# 11              Virginia     8631393
# 12            Washington     7705281
# 13               Arizona     7151502
# 14         Massachusetts     7029917
# 15             Tennessee     6910840
# 16               Indiana     6785528
# 17              Maryland     6177224
# 18              Missouri     6154913
# 19             Wisconsin     5893718
# 20              Colorado     5773714
# 21             Minnesota     5706494
# 22        South Carolina     5118425
# 23               Alabama     5024279
# ...

# %%
#0 is City
#1 is State
#2 is Popl.
DFwiki.iloc[:,0]
# Out:
# 0               California
# 1                    Texas
# 2                  Florida
# 3                 New York
# 4             Pennsylvania
# 5                 Illinois
# 6                     Ohio
# 7                  Georgia
# 8           North Carolina
# 9                 Michigan
# 10              New Jersey
# 11                Virginia
# 12              Washington
# 13                 Arizona
# 14           Massachusetts
# 15               Tennessee
# 16                 Indiana
# 17                Maryland
# 18                Missouri
# 19               Wisconsin
# 20                Colorado
# 21               Minnesota
# 22          South Carolina
# 23                 Alabama
# 24               Louisiana
# 25                Kentucky
# 26                  Oregon
# 27                Oklahoma
# 28             Connecticut
# 29                    Utah
# 30                    Iowa
# 31                  Nevada
# 32                Arkansas
# 33             Mississippi
# ...

# %%
#prepare a frequency table to detect possible errors
DFwiki.Population.value_counts()
# Out:
# 39538223    1
# 1793716     1
# 3605944     1
# 3271616     1
# 3190369     1
# 3104614     1
# 3011524     1
# 2961279     1
# 2937880     1
# 2117522     1
# 1961504     1
# 1839106     1
# 1455271     1
# 4237256     1
# 1377529     1
# 1362359     1
# 1097379     1
# 1084225     1
# 989948      1
# 886667      1
# 779094      1
# 733391      1
# 689545      1
# 643077      1
# 3959353     1
# 4505836     1
# 29145505    1
# 7705281     1
# 21538187    1
# 20201249    1
# 13002700    1
# 12812508    1
# 11799448    1
# 10711908    1
# 10439388    1
# 10077331    1
# 9288994     1
# 8631393     1
# 7151502     1
# 4657757     1
# 7029917     1
# 6910840     1
# 6785528     1
# 6177224     1
# 6154913     1
# 5893718     1
# 5773714     1
# 5706494     1
# 5118425     1
# 5024279     1
# 576851      1
# Name: Population, dtype: int64

# %%
#save the frequency table
tableCounts=DFwiki.Population.value_counts()
tableCounts
# Out:
# 39538223    1
# 1793716     1
# 3605944     1
# 3271616     1
# 3190369     1
# 3104614     1
# 3011524     1
# 2961279     1
# 2937880     1
# 2117522     1
# 1961504     1
# 1839106     1
# 1455271     1
# 4237256     1
# 1377529     1
# 1362359     1
# 1097379     1
# 1084225     1
# 989948      1
# 886667      1
# 779094      1
# 733391      1
# 689545      1
# 643077      1
# 3959353     1
# 4505836     1
# 29145505    1
# 7705281     1
# 21538187    1
# 20201249    1
# 13002700    1
# 12812508    1
# 11799448    1
# 10711908    1
# 10439388    1
# 10077331    1
# 9288994     1
# 8631393     1
# 7151502     1
# 4657757     1
# 7029917     1
# 6910840     1
# 6785528     1
# 6177224     1
# 6154913     1
# 5893718     1
# 5773714     1
# 5706494     1
# 5118425     1
# 5024279     1
# 576851      1
# Name: Population, dtype: int64

# %%
#keep the names of the rows as a list (indexes as list)
badLevels=tableCounts[tableCounts==1].index.to_list()
badLevels
# Out:
# [39538223,
#  1793716,
#  3605944,
#  3271616,
#  3190369,
#  3104614,
#  3011524,
#  2961279,
#  2937880,
#  2117522,
#  1961504,
#  1839106,
#  1455271,
#  4237256,
#  1377529,
#  1362359,
#  1097379,
#  1084225,
#  989948,
#  886667,
#  779094,
#  733391,
#  689545,
#  643077,
#  3959353,
#  4505836,
#  29145505,
#  7705281,
#  21538187,
#  20201249,
#  13002700,
#  12812508,
#  11799448,
#  10711908,
#  10439388,
#  10077331,
#  9288994,
#  8631393,
#  7151502,
#  4657757,
#  7029917,
#  6910840,
#  6785528,
#  6177224,
#  6154913,
#  5893718,
#  5773714,
#  5706494,
#  5118425,
#  5024279,
#  576851]

# %%
#are these wrong?
DFwiki[DFwiki.Population.isin(badLevels)]
# Out:
#                    State  Population
# 0             California    39538223
# 1                  Texas    29145505
# 2                Florida    21538187
# 3               New York    20201249
# 4           Pennsylvania    13002700
# 5               Illinois    12812508
# 6                   Ohio    11799448
# 7                Georgia    10711908
# 8         North Carolina    10439388
# 9               Michigan    10077331
# 10            New Jersey     9288994
# 11              Virginia     8631393
# 12            Washington     7705281
# 13               Arizona     7151502
# 14         Massachusetts     7029917
# 15             Tennessee     6910840
# 16               Indiana     6785528
# 17              Maryland     6177224
# 18              Missouri     6154913
# 19             Wisconsin     5893718
# 20              Colorado     5773714
# 21             Minnesota     5706494
# 22        South Carolina     5118425
# 23               Alabama     5024279
# ...

# %%
DFwiki.reset_index()
# Out:
#     index                 State  Population
# 0       0            California    39538223
# 1       1                 Texas    29145505
# 2       2               Florida    21538187
# 3       3              New York    20201249
# 4       4          Pennsylvania    13002700
# 5       5              Illinois    12812508
# 6       6                  Ohio    11799448
# 7       7               Georgia    10711908
# 8       8        North Carolina    10439388
# 9       9              Michigan    10077331
# 10     10            New Jersey     9288994
# 11     11              Virginia     8631393
# 12     12            Washington     7705281
# 13     13               Arizona     7151502
# 14     14         Massachusetts     7029917
# 15     15             Tennessee     6910840
# 16     16               Indiana     6785528
# 17     17              Maryland     6177224
# 18     18              Missouri     6154913
# 19     19             Wisconsin     5893718
# ...

# %%
DFwiki.reset_index(drop=True, inplace=True)
#
DFwiki
# Out:
#                    State  Population
# 0             California    39538223
# 1                  Texas    29145505
# 2                Florida    21538187
# 3               New York    20201249
# 4           Pennsylvania    13002700
# 5               Illinois    12812508
# 6                   Ohio    11799448
# 7                Georgia    10711908
# 8         North Carolina    10439388
# 9               Michigan    10077331
# 10            New Jersey     9288994
# 11              Virginia     8631393
# 12            Washington     7705281
# 13               Arizona     7151502
# 14         Massachusetts     7029917
# 15             Tennessee     6910840
# 16               Indiana     6785528
# 17              Maryland     6177224
# 18              Missouri     6154913
# 19             Wisconsin     5893718
# 20              Colorado     5773714
# 21             Minnesota     5706494
# 22        South Carolina     5118425
# 23               Alabama     5024279
# ...
